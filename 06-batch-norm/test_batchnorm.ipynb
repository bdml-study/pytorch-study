# %%
import torch
from torch import nn
from models.batch_norm import BatchNormalization

# %%
torch.manual_seed(13)
x = torch.randn(2, 8, 16, 16)

# %%
batchnorm = nn.BatchNorm2d(8)
batchnorm_custom = BatchNormalization(8)

# %%
batchnorm(x)
# Out:
# tensor([[[[ 0.4382,  0.3719,  1.5684,  ...,  0.1757, -0.1491,  1.9620],
#           [ 0.7544, -0.4156, -1.5656,  ...,  1.0797,  0.2625,  1.8349],
#           [ 1.3304,  1.7504,  0.5635,  ..., -0.7314, -0.4924,  0.4643],
#           ...,
#           [ 0.8388, -0.2456, -0.3327,  ..., -2.0421,  0.4928,  0.2187],
#           [ 1.2711,  1.2829,  0.1879,  ..., -0.2198, -1.1106, -1.0430],
#           [-1.0097, -0.4950, -0.4114,  ..., -0.1506,  0.8767, -1.8582]],
#
#          [[ 1.7371, -0.2457,  0.2825,  ..., -0.1646, -1.1118, -0.2293],
#           [ 0.3974,  1.3079,  0.4553,  ...,  0.8347, -0.4943, -0.1429],
#           [ 0.6603,  0.3388,  0.6315,  ...,  0.5345, -0.5179, -0.9273],
#           ...,
#           [-0.7521,  0.9317, -0.7114,  ...,  0.4195,  0.0627, -1.4284],
#           [-0.8481, -1.6070, -1.0552,  ...,  0.6475, -0.6150, -0.7381],
#           [-0.0804, -0.2453,  1.4188,  ..., -0.3044,  0.3489,  0.3997]],
#
# ...

# %%
batchnorm_custom(x)
# Out:
# tensor([[[[ 0.4378,  0.3716,  1.5669,  ...,  0.1755, -0.1489,  1.9600],
#           [ 0.7536, -0.4152, -1.5641,  ...,  1.0786,  0.2623,  1.8331],
#           [ 1.3291,  1.7487,  0.5629,  ..., -0.7307, -0.4919,  0.4638],
#           ...,
#           [ 0.8380, -0.2454, -0.3323,  ..., -2.0402,  0.4923,  0.2185],
#           [ 1.2699,  1.2816,  0.1877,  ..., -0.2195, -1.1095, -1.0420],
#           [-1.0087, -0.4946, -0.4110,  ..., -0.1505,  0.8758, -1.8564]],
#
#          [[ 1.7355, -0.2455,  0.2822,  ..., -0.1645, -1.1107, -0.2291],
#           [ 0.3970,  1.3066,  0.4549,  ...,  0.8339, -0.4938, -0.1427],
#           [ 0.6596,  0.3384,  0.6309,  ...,  0.5340, -0.5174, -0.9264],
#           ...,
#           [-0.7514,  0.9308, -0.7107,  ...,  0.4191,  0.0627, -1.4270],
#           [-0.8473, -1.6054, -1.0542,  ...,  0.6468, -0.6144, -0.7374],
#           [-0.0803, -0.2451,  1.4174,  ..., -0.3041,  0.3485,  0.3993]],
#
# ...
