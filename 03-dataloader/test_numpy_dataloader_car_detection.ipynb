# %%
from utils.car_dataloader import CarDataLoader
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# %%
BATCH_SIZE = 8

# %%
dloader = CarDataLoader(BATCH_SIZE)

# %%
for b, (images, bboxes) in enumerate(dloader):
    print(f"Batch {b}")
    
    images = np.transpose(images, [0, 2, 3, 1]) + 0.5
    bboxes = bboxes.astype(np.int32)
    
    fig, axes = plt.subplots(1, BATCH_SIZE, figsize=(BATCH_SIZE*3, 3))
    
    for i in range(BATCH_SIZE):
        axes[i].imshow(images[i])
        axes[i].set_xticks([])
        axes[i].set_yticks([])
        
        xy = bboxes[i, :2]
        width, height = bboxes[i, 2] - bboxes[i, 0], bboxes[i, 3] - bboxes[i, 1]
        
        axes[i].add_patch(patches.Rectangle(xy, width, height, fill=False, edgecolor="red"))
        
    plt.show()
    
    if b == 3:
        break
# Out:
# Batch 0
# Batch 1
# Batch 2
# Batch 3
